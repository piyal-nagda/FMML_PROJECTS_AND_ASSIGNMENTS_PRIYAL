# %% [markdown]
# <a href="https://colab.research.google.com/github/piyal-nagda/FMML_PROJECTS_AND_ASSIGNMENTS_PRIYAL/blob/main/FMML_M8L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-23 12:42:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   233MB/s    in 0.3s
#
# 2025-03-23 12:42:51 (233 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3730 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2905 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 38  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7785   1803.03759v1  The problem of identifying voice commands has ...  stat
# 5473    1406.3926v1  We study Bayesian optimal control of a general...    cs
# 6658   1704.08715v1  A Siamese Deep Forest (SDF) is proposed in the...  stat
# 5231    1203.3497v1  Most conventional Reinforcement Learning (RL) ...    cs
# 22794  1706.09880v4  Interpreting gradient methods as fixed-point i...  stat
# ...             ...                                                ...   ...
# 13457   1107.4414v1  This work presents, the classification of user...    cs
# 37091  1607.02018v1  In ontology-based data access, databases are c...    cs
# 30536  1712.04926v1  In this paper we propose an ensemble of local ...    cs
# 8859   1605.04122v1  This paper is a reflexion on the computability...    cs
# 12028  1706.05378v2  We propose an alternative framework to existin...  stat
#
#                                                    title  year  \
# 7785   Speech Recognition: Keyword Spotting Through I...  2018
# 5473   Bayesian Optimal Control of Smoothly Parameter...  2014
# 6658                               A Siamese Deep Forest  2017
# 5231   Parametric Return Density Estimation for Reinf...  2012
# 22794  A Fixed-Point of View on Gradient Methods for ...  2017
# ...                                                  ...   ...
# 13457  Frequency based Classification of Activities u...  2011
# 37091  Mapping Data to Ontologies with Exceptions Usi...  2016
# 30536  Object Classification using Ensemble of Local ...  2017
# 8859        Natural Language Semantics and Computability  2016
# 12028  A framework for Multi-A(rmed)/B(andit) testing...  2017
#
#                                                 keywords
# 7785   [identifying, challenge, variability, efficaci...
# 5473   [parameterized, computing, computationally, ex...
# 6658   [modification, alternative, consisting, concat...
# 5231   [conventional, reinforcement, algorithms, espe...
# 22794  [interpreting, iterations, minimizing, objecti...
# ...                                                  ...
# 13457  [classification, activities, frequency, compon...
# 37091  [databases, connected, relational, databases, ...
# 30536  [classification, effectiveness, representation...
# 8859   [reflexion, computability, semantics, semantic...
# 12028  [alternative, framework, controlling, practica...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7785     [identifying, challenge, variability, efficaci...
# 5473     [parameterized, computing, computationally, ex...
# 6658     [modification, alternative, consisting, concat...
# 5231     [conventional, reinforcement, algorithms, espe...
# 22794    [interpreting, iterations, minimizing, objecti...
#                                ...
# 12905    [computational, intelligence, artificial, inte...
# 35750    [addresses, distributions, constraints, partic...
# 15837    [distributed, representation, explicitly, fact...
# 19266    [controversy, automated, combining, propagatin...
# 1673     [introduce, libraries, conversational, managem...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8933 words.
# Out of those 4590 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e0a1cdbe-67c8-4840-a8ce-fb40899a81a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0a1cdbe-67c8-4840-a8ce-fb40899a81a0")) {                    Plotly.newPlot(                        "e0a1cdbe-67c8-4840-a8ce-fb40899a81a0",                        [{"x":["regularizer","identifying","potential","classification","developed","promising","challenge","recommended","applications","techniques","tensorflow","adversarially","architectures","functioning","adversarial","implemented","convolutional","demonstrate","applicability","additionally","determine","particular","technique","recognition","variability","demonstration","maintains","importantly","distribution","parameterized","algorithm","computational","computation","expensive","computing","effectiveness","performance","efficiency","parameter","sufficiently","application","posterior","computationally","alternative","concatenated","distances","overfitting","illustrate","modification","distributions","probabilities","consisting","numerical","quadratic","determined","dissimilar","experiments","available","optimization","sometimes","densities","extension","estimation","environment","conditional","conventional","probability","instances","presented","estimating","parametric","reinforcement","preferred","management","sensitive","especially","algorithms","paradigms","accelerated","convergence","transformation","conceptual","associated","objective","iterations","functions","stochastic","simplicity","algorithmic","minimizing","interpreting","derivation","preserving","properties","considered","conveniently","gradients","detection","including","competitive","generalization","containing","naturally","confidence","evaluations","likelihood","localization","locations","corresponding","replicating","benchmarks","predicted","narrowing","providing","testament","consistency","constraint","andersson","interpretation","assumptions","efficient","scoresearch","conjecture","faithfulness","development","compromises","discovered","discovering","trajectories","concentrated","approaches","introduce","intention","trajectory","framework","challenging","according","impressively","prediction","correlation","discriminative","exhibiting","excellent","background","situations","alleviate","information","benchmark","necessary","predictions","typically","introduced","proprietary","transparency","transparent","criterion","knowledge","distillation","calibrate","interactions","intervals","comparing","distortion","significant","comparison","permutation","diversified","solutions","incorporate","variables","accompanied","collection","connections","permutations","augmentation","operation","collections","strategies","generality","binarization","processes","assignments","clustering","metaheuristic","significantly","partitioning","resulting","flexibility","illustrations","scheduling","procedures","diversification","previously","theoretic","formalize","feasibility","communication","autonomous","interaction","discussed"],"y":[20,74,150,497,198,110,140,5,425,370,4,5,103,4,94,101,389,557,36,62,73,267,259,389,28,13,18,32,234,12,825,284,149,76,139,221,847,174,134,18,255,47,96,108,7,26,22,70,19,113,71,46,71,34,46,5,604,308,312,22,8,67,207,148,101,97,185,106,183,63,30,112,12,39,68,125,587,11,15,117,51,19,128,193,21,190,119,26,44,53,14,13,63,216,120,4,29,364,236,110,105,59,55,30,52,56,73,39,125,4,92,40,1,89,1,64,84,1,42,72,419,0,14,1,125,1,28,28,30,5,473,345,12,24,515,241,96,2,269,70,96,12,31,71,51,25,691,217,68,96,97,116,1,3,2,51,365,6,2,90,13,69,19,247,141,6,3,155,59,133,6,78,48,9,33,38,20,104,9,7,104,13,151,7,272,16,163,26,2,25,34,5,106,41,11,25,69,54,91,58],"type":"bar"},{"x":["regularizer","identifying","potential","classificat ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4590,), (4590, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8258333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Glottochronology</span> <span style=''>and</span> <span style=''>problems</span> <span style=''>of</span> <span style=''>protolanguage</span> <span style='background-color:rgba(0, 255, 0, 0.3984962406015037);'>reconstruction</span> <br/><br/><span style=''>A</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8857142857142857);'>languages</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>genealogical</span> <span style=''>trees</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>is</span> <span style=''>proposed</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Augment</span> <span style=''>and</span> <span style=''>Conquer</span> <span style=''>Negative</span> <span style=''>Binomial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developing</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>augmentation</span> <span style=''>methods</span> <span style=''>unique</span> <span style=''>to</span> <span style=''>the</span> <span style=''>negative</span> <span style=''>binomial</span> <span style=''>(NB)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>we</span> <span style=''>unite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>seemingly</span> <span style=''>disjoint</span> <span style=''>count</span> <span style=''>and</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>under</span> <span style=''>the</span> <span style=''>NB</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>We</span> <span style=''>develop</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>models</span> <span style=''>and</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>Gibbs</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>gamma</span> <span style=''>NB</span> <span style=''>process</span> <span style=''>can</span> <span style=''>be</span> <span style=''>reduced</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>process</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>highlighting</span> <span style=''>its</span> <span style=''>unique</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantages</span> <span style=''>A</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>NB</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>with</span> <span style=''>distinct</span> <span style=''>sharing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanisms</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>and</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>topic</span> <span style=''>modeling</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connections</span> <span style=''>to</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>showing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style=''>both</span> <span style=''>the</span> <span style=''>NB</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dispersion</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background- ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3846153846153846);'>Parametrized</span> <span style='background-color:rgba(255, 0, 0, 0.3720316622691293);'>Stochastic</span> <span style=''>Multi</span> <span style=''>armed</span> <span style=''>Bandits</span> <span style=''>with</span> <span style=''>Binary</span> <span style=''>Rewards</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandits</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>possibly</span> <span style=''>infinite</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlated</span> <span style=''>arms</span> <span style=''>We</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>the</span> <span style=''>arms</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.47368421052631576);'>Bernoulli</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>rewards</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>across</span> <span style=''>time</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style=''>success</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3846153846153846);'>parametrized</span> <span style=''>by</span> <span style=''>known</span> <span style='background-color:rgba(0, 255, 0, 0.3898305084745763);'>attribute</span> <span style=''>vectors</span> <span style=''>for</span> <span style=''>each</span> <span style=''>arm</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>an</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preference</span> <span style=''>vector</span> <span style=''>each</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4166666666666667);'>dimension</span> <span style=''>n</span> <span style=''>For</span> <span style=''>this</span> <span style=''>model</span> <span style=''>we</span> <span style=''>seek</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>a</span> <span style=''>total</span> <span style=''>regret</span> <span style=''>that</span> <span style=''>is</span> <span style=''>sub</span> <span style=''>linear</span> <span style=''>in</span> <span style=''>time</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>of</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>arms</span> <span style=''>We</span> <span style=''>present</span> <span style=''>such</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>we</span> <span style=''>call</span> <span style=''>the</span> <span style=''>Two</span> <span style=''>Phase</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>and</span> <span style=''>analyze</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>We</span> <span style=''>show</span> <span style=''>upper</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style=''>total</span> <span style=''>regret</span> <span style=''>which</span> <span style=''>applies</span> <span style='background-color:rgba(255, 0, 0, 0.37931034482758624);'>unif ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Systematic</span> <span style=''>Ensemble</span> <span style=''>Learning</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivation</span> <span style=''>of</span> <span style=''>this</span> <span style=''>work</span> <span style=''>is</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>standard</span> <span style=''>stacking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>which</span> <span style=''>are</span> <span style=''>composed</span> <span style=''>of</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneous</span> <span style=''>base</span> <span style=''>models</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>stages</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensions</span> <span style=''>to</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>stacking</span> <span style=''>approach</span> <span style=''>In</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>we</span> <span style=''>combine</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>standard</span> <span style=''>stacking</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>into</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ensembles</span> <span style=''>using</span> <span style=''>a</span> <span style=''>two</span> <span style=''>step</span> <span style=''>ensemble</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>setting</span> <span style=''>The</span> <span style=''>second</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>two</span> <span style=''>parts</span> <span style=''>In</span> <span style=''>the</span> <span style=''>initial</span> <span style=''>part</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diversity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanism</span> <span style=''>is</span> <span style=''>injected</span> <span style=''>into</span> <span style=''>the</span> <span style=''>original</span> <span style=''>training</span> <span style=''>data</span> <span style=''>set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>systematically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>training</span> <span style=''>subsets</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitions</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0,  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13225806451612904)
# 	knowledge (0.13082437275985664)
# 	architecture (0.09211469534050179)
# 	information (0.24767025089605735)
# 	segmentation (0.07741935483870968)
# 	representation (0.14121863799283155)
# 	different (0.2637992831541219)
# 	detection (0.13046594982078852)
# 	recognition (0.13942652329749103)
# 	convolutional (0.13942652329749103)
#
# Some Statistics words are:
# 	likelihood (0.10298507462686567)
# 	stochastic (0.12935323383084577)
# 	variables (0.1407960199004975)
# 	algorithm (0.3890547263681592)
# 	distribution (0.1791044776119403)
# 	estimation (0.17960199004975125)
# 	statistical (0.16467661691542287)
# 	dimensional (0.18009950248756218)
# 	regression (0.16517412935323383)
# 	inference (0.20248756218905473)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f2c7ace7-e9ad-448e-baae-cfeba5deb7f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2c7ace7-e9ad-448e-baae-cfeba5deb7f0")) {                    Plotly.newPlot(                        "f2c7ace7-e9ad-448e-baae-cfeba5deb7f0",                        [{"x":["regularizer","identifying","potential","classification","developed","promising","challenge","recommended","applications","techniques","tensorflow","adversarially","architectures","functioning","adversarial","implemented","convolutional","demonstrate","applicability","additionally","determine","particular","technique","recognition","variability","demonstration","maintains","importantly","distribution","parameterized","algorithm","computational","computation","expensive","computing","effectiveness","performance","efficiency","parameter","sufficiently","application","posterior","computationally","alternative","concatenated","distances","overfitting","illustrate","modification","distributions","probabilities","consisting","numerical","quadratic","determined","dissimilar","experiments","available","optimization","sometimes","densities","extension","estimation","environment","conditional","conventional","probability","instances","presented","estimating","parametric","reinforcement","preferred","management","sensitive","especially","algorithms","paradigms","accelerated","convergence","transformation","conceptual","associated","objective","iterations","functions","stochastic","simplicity","algorithmic","minimizing","interpreting","derivation","preserving","properties","considered","conveniently","gradients","detection","including","competitive","generalization","containing","naturally","confidence","evaluations","likelihood","localization","locations","corresponding","replicating","benchmarks","predicted","narrowing","providing","testament","consistency","constraint","andersson","interpretation","assumptions","efficient","scoresearch","conjecture","faithfulness","development","compromises","discovered","discovering","trajectories","concentrated","approaches","introduce","intention","trajectory","framework","challenging","according","impressively","prediction","correlation","discriminative","exhibiting","excellent","background","situations","alleviate","information","benchmark","necessary","predictions","typically","introduced","proprietary","transparency","transparent","criterion","knowledge","distillation","calibrate","interactions","intervals","comparing","distortion","significant","comparison","permutation","diversified","solutions","incorporate","variables","accompanied","collection","connections","permutations","augmentation","operation","collections","strategies","generality","binarization","processes","assignments","clustering","metaheuristic","significantly","partitioning","resulting","flexibility","illustrations","scheduling","procedures","diversification","previously","theoretic","formalize","feasibility","communication","autonomous","interaction","discussed","implementation","attribute","considers","methodological","furthermore","evaluated","uncertainty","multilabel","architecture","adjusting","pessimistic","optimistic","improving","evaluation","predictive","prewhitening","direction","synthetic","iterative","extraction","capabilities","polynomial","asymptotic","illustrated","biomedical","decomposing","particularly","electrocardiograms","processing","component","independent","fibrillation","implementations","demonstrated","deflation","algebraic","maximization","components","performing","performed","iteration","comparative","outperforms","statistically","involving","practical","monotonically","iteratively","important","majorization","construction","minimization","re ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	scoresearch
# 	prewhitening
# 	deflation
# 	penalizations
# 	astronomical
# 	telescope
# 	ferromagnetic
# 	prognostics
# 	unnecessarily
# 	minimality
# 	representer
# 	exchangeable
# 	parametrically
# 	attacking
# 	resistance
# 	worsening
# 	unavoidably
# 	conjugacy
# 	formidable
# 	looseness
# Some words which never appear in Statistics papers:
# 	metaheuristic
# 	diversification
# 	notorious
# 	archaeological
# 	threefold
# 	assembling
# 	milliseconds
# 	continues
# 	exquisite
# 	exactitude
# 	illuminations
# 	lambertian
# 	occlusions
# 	detections
# 	monocular
# 	articulated
# 	congestion
# 	traveling
# 	downsampling
# 	overestimates

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077870113881194e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7758333333333334
